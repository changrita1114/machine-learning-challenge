# %%
from sklearn import tree
import pandas as pd
import os

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
target = df["koi_disposition"]
target_names = ["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]

# %%
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf = rf.fit(X_train_minmax, y_train)
rf.score(X_test_minmax, y_test)
# Out:
# 0.898741418764302

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10372106564645803, 'koi_fpflag_co'),
#  (0.09232482583717136, 'koi_fpflag_nt'),
#  (0.06529202914143178, 'koi_fpflag_ss'),
#  (0.054610274899717696, 'koi_model_snr'),
#  (0.05026430798985402, 'koi_prad'),
#  (0.03733721624738869, 'koi_duration_err1'),
#  (0.03512256509944682, 'koi_fpflag_ec'),
#  (0.034433927841670944, 'koi_steff_err1'),
#  (0.032725706872773534, 'koi_duration_err2'),
#  (0.026717614265280583, 'koi_depth'),
#  (0.0266113713553903, 'koi_time0bk_err2'),
#  (0.025868787699637387, 'koi_prad_err2'),
#  (0.025727473053178223, 'koi_time0bk_err1'),
#  (0.02445065382963991, 'koi_steff_err2'),
#  (0.023856083076733977, 'koi_prad_err1'),
#  (0.022537847502533202, 'koi_period'),
#  (0.022264101221691927, 'koi_duration'),
#  (0.02183219600663477, 'koi_period_err2'),
#  (0.020697469873577436, 'koi_period_err1'),
#  (0.02015300153808735, 'koi_impact'),
#  (0.017484683039385683, 'koi_teq'),
#  (0.017241049234828845, 'koi_insol_err1'),
#  (0.017000094091579352, 'koi_depth_err2'),
#  (0.015866991198350663, 'koi_insol'),
#  (0.012656001055411743, 'koi_depth_err1'),
#  (0.012619134978333281, 'koi_time0bk'),
#  (0.012513297294927997, 'ra'),
#  (0.012231815576716976, 'koi_insol_err2'),
#  (0.011873119878221547, 'dec'),
#  (0.011650925994605703, 'koi_impact_err1'),
#  (0.01142927457319034, 'koi_srad_err1'),
#  (0.011113656105664307, 'koi_impact_err2'),
#  (0.010608645994629302, 'koi_kepmag'),
#  (0.010458213447091025, 'koi_slogg_err2'),
#  (0.01002206311271347, 'koi_srad'),
#  (0.009938996969784657, 'koi_steff'),
#  (0.008926024088415453, 'koi_slogg'),
#  (0.008671522044082712, 'koi_srad_err2'),
#  (0.00820604766645924, 'koi_slogg_err1'),
#  (0.0029399246573098003, 'koi_tce_plnt_num')]

# %%
predictions = rf.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0     FALSE POSITIVE  FALSE POSITIVE
# 1     FALSE POSITIVE       CANDIDATE
# 2     FALSE POSITIVE  FALSE POSITIVE
# 3     FALSE POSITIVE  FALSE POSITIVE
# 4     FALSE POSITIVE  FALSE POSITIVE
# ...              ...             ...
# 1743  FALSE POSITIVE       CANDIDATE
# 1744  FALSE POSITIVE       CANDIDATE
# 1745  FALSE POSITIVE       CONFIRMED
# 1746  FALSE POSITIVE       CONFIRMED
# 1747  FALSE POSITIVE       CONFIRMED
#
# [1748 rows x 2 columns]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators":[200,500,1000]}
 
grid = GridSearchCV(rf,param_grid, verbose=3)

# %%
# Train the model with GridSearch
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................... n_estimators=200, score=0.904, total=   2.2s
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [CV] .................... n_estimators=200, score=0.907, total=   2.0s
# [CV] n_estimators=200 ................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.2s remaining:    0.0s
# [CV] .................... n_estimators=200, score=0.888, total=   2.0s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.886, total=   2.1s
# [CV] n_estimators=200 ................................................
# [CV] .................... n_estimators=200, score=0.878, total=   1.9s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.903, total=   5.1s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.907, total=   5.4s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.887, total=   5.1s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.882, total=   5.3s
# [CV] n_estimators=500 ................................................
# [CV] .................... n_estimators=500, score=0.884, total=   5.2s
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.908, total=  10.1s
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.907, total=   9.7s
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.889, total=  10.3s
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.880, total=  11.8s
# [CV] n_estimators=1000 ...............................................
# [CV] ................... n_estimators=1000, score=0.882, total=  11.9s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  1.5min finished
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [200, 500, 1000]}, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'n_estimators': 1000}
# 0.8929955100823029

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'RandomForest.sav'
joblib.dump(grid, filename)
# Out:
# ['RandomForest.sav']

# %%
joblib.load('RandomForest.sav')
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [200, 500, 1000]}, verbose=3)
